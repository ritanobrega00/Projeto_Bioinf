# %% [markdown]
# # **Pipeline for variant caling in *Mtb***
#
# This Jupyter Notebook has been developed by Rita Nóbrega-Martins (PG46733) for the curicular unit 'Project' of the Master's in Bioinformatics, University of Minho.
# This work has been supervised by Dr. Nuno Osório (ICVS, University of Minho) and Dr. Tiago Beites (i3S, University of Porto).

# %% [markdown]
# This pipeline runs on Linux system or WSL-Ubuntu that runs a conda environment named 'MTB_calling'.
# This conda environment contains the following tools:
# * `bcftools`              version   1.11
# * `bedtools`              version   2.30.0
# * `bwa`                   version   0.7.17
# * `bzip2`                 version   1.0.8
# * `fastqc`                version   0.12.1
# * `htslib`                version   1.19.1
# * `ipykernel`             version   6.29.3
# * `ipython`               version   8.22.2
# * `lofreq`                version   2.1.5
# * `mosdepth`              version   0.3.3
# * `multiqc`               version   1.21
# * `parallel`              version   20160622
# * `pathogen-profiler`     version   2.0.1
# * `samtools`              version   1.12
# * `sra-tools`             version   3.1.0
# * `tabixpp`               version   1.1.2
# * `tb-profiler`           version   4.3.0
# * `trimmomatic`           version   0.39
# * `vcflib`                version   1.0.9

# %%
conda activate MTB_calling

# %% [markdown]
# # **1.FASTQ extraction**
#
# **Input:** Text file with a list of SRA accession numbers of the *Mtb* isolates
#
# The funcion `extractSRAfiles()` iterates each line of the text file cointaining the SRA number of a given isolate, creating a directory for each isolate/sample, where information and files regarding that specific isolate will be stored.
#
# Through the tools `prefetch` and `fasterq-dump`, SRA data will be downnloaded from the NCBI database, and converted to FastQ files [1].
#
# **Output:** 2 FastQ files per sample

# %%
extractSRAfiles () {
    echo "Extracting FastQ files"
    local sample="$1" 
    local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads"

    while IFS= read -r sample; do
        echo -e "\nSample: $sample"
        mkdir -p "$sra_diretoria/$sample"  
        cd "$sra_diretoria/$sample" || exit 1 

        prefetch "$sample" 
        fasterq-dump "$sample"
        rm $HOME/Projeto_Mtb/SRA_files/sra/"$sample".sra
    
    done < "$sample"
}

# %%
extractSRAfiles ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Extracting FastQ files
#
# Sample: DRR034421
#
# 2024-06-14T14:02:52 prefetch.3.1.0: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2024-06-14T14:02:52 prefetch.3.1.0: 1) 'DRR034421' is found locally
# 2024-06-14T14:02:52 prefetch.3.1.0: 'DRR034421' has 0 unresolved dependencies
# spots read      : 606,259
# reads read      : 1,212,518
# reads written   : 1,212,518
#
# Sample: DRR130077
#
# 2024-06-14T14:03:10 prefetch.3.1.0: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2024-06-14T14:03:10 prefetch.3.1.0: 1) 'DRR130077' is found locally
# 2024-06-14T14:03:11 prefetch.3.1.0: 'DRR130077' has 0 unresolved dependencies
# spots read      : 573,970
# reads read      : 1,147,940
# reads written   : 1,147,940
#
# Sample: DRR130078
#
# 2024-06-14T14:03:31 prefetch.3.1.0: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2024-06-14T14:03:32 prefetch.3.1.0: 1) 'DRR130078' is found locally
# 2024-06-14T14:03:32 prefetch.3.1.0: 'DRR130078' has 0 unresolved dependencies
# spots read      : 863,537
# reads read      : 1,727,074
# reads written   : 1,727,074
#
# Sample: DRR130093
#
# 2024-06-14T14:04:10 prefetch.3.1.0: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2024-06-14T14:04:10 prefetch.3.1.0: 1) 'DRR130093' is found locally
# 2024-06-14T14:04:10 prefetch.3.1.0: 'DRR130093' has 0 unresolved dependencies
# spots read      : 1,368,077
# reads read      : 2,736,154
# reads written   : 2,736,154

# %% [markdown]
# # **2. Reads Pre-processing**
#
# The pre-processing of the reads present in the FASTQ-files extracted consists on extraction of the FASTQC file, which contain a Quality Report, and the trimming of the reads according to its quality.
#
# The function `quality_control` receives the text file with the list of isolates and iterates through each line/isolate to access the sample folder and through `fastqc` download the FASTQC-file (in a html format) per FASTQ-file, with relevant information for the assessment of the quality of the reads.
#
# The function `trimming_bbduk` iterates through the lines of the text file given as an input to access the 2 FASTQ-files of each isolate/sample and perform a trimming of the reads through the `BBDuk` tool [2] to remove adapters and low-quality reads, as well as reads that may be too short for further analysis.
# `trimming_bbduk` returns the 2 FASTQ-files with the trimmed reads per sample.

# %%
quality_control () {
  echo 'Quality control'
  local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads"
  local sample_file="$1"
  sed -i 's/\r$//' "$sample_file"  

  if [ ! -f "$sample_file" ]; then
      echo "Sample '$sample_file' file not found."
      return 1
  fi

  parallel -j "$(nproc)" "
      sample={};
      if [ -f \"$sra_diretoria/\$sample/\${sample}_1.fastq\" ] && [ -f \"$sra_diretoria/\$sample/\${sample}_2.fastq\" ]; then
          fastqc \"$sra_diretoria/\$sample/\${sample}_1.fastq\" \"$sra_diretoria/\$sample/\${sample}_2.fastq\";
      else
          echo \"FASTQ not found for: '\$sample'.\";
      fi
    " < "$sample_file"
}

    # vizualização da qualidade - basta o report html ou uso o Qualitymap ou o fastxtoolkit (permitem ver na command line)

# %%
quality_control ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Quality control
# Academic tradition requires you to cite works you base your article on.
# When using programs that use GNU Parallel to process data for publication
# please cite:
#
#   O. Tange (2011): GNU Parallel - The Command-Line Power Tool,
#   ;login: The USENIX Magazine, February 2011:42-47.
#
# This helps funding further development; AND IT WON'T COST YOU A CENT.
# If you pay 10000 EUR you should feel free to use GNU Parallel without citing.
#
# To silence the citation notice: run 'parallel --citation'.
#
# null
# null
# Analysis complete for DRR034421_1.fastq
# Analysis complete for DRR034421_2.fastq
# Started analysis of DRR034421_1.fastq
# Approx 5% complete for DRR034421_1.fastq
# Approx 10% complete for DRR034421_1.fastq
# Approx 15% complete for DRR034421_1.fastq
# Approx 20% complete for DRR034421_1.fastq
# Approx 25% complete for DRR034421_1.fastq
# Approx 30% complete for DRR034421_1.fastq
# Approx 35% complete for DRR034421_1.fastq
# Approx 40% complete for DRR034421_1.fastq
# Approx 45% complete for DRR034421_1.fastq
# Approx 50% complete for DRR034421_1.fastq
# Approx 55% complete for DRR034421_1.fastq
# Approx 60% complete for DRR034421_1.fastq
# Approx 65% complete for DRR034421_1.fastq
# Approx 70% complete for DRR034421_1.fastq
# Approx 75% complete for DRR034421_1.fastq
# Approx 80% complete for DRR034421_1.fastq
# Approx 85% complete for DRR034421_1.fastq
# Approx 90% complete for DRR034421_1.fastq
# Approx 95% complete for DRR034421_1.fastq
# Started analysis of DRR034421_2.fastq
# Approx 5% complete for DRR034421_2.fastq
# Approx 10% complete for DRR034421_2.fastq
# Approx 15% complete for DRR034421_2.fastq
# Approx 20% complete for DRR034421_2.fastq
# Approx 25% complete for DRR034421_2.fastq
# Approx 30% complete for DRR034421_2.fastq
# Approx 35% complete for DRR034421_2.fastq
# Approx 40% complete for DRR034421_2.fastq
# Approx 45% complete for DRR034421_2.fastq
# Approx 50% complete for DRR034421_2.fastq
# Approx 55% complete for DRR034421_2.fastq
# Approx 60% complete for DRR034421_2.fastq
# Approx 65% complete for DRR034421_2.fastq
# Approx 70% complete for DRR034421_2.fastq
# Approx 75% complete for DRR034421_2.fastq
# Approx 80% complete for DRR034421_2.fastq
# Approx 85% complete for DRR034421_2.fastq
# Approx 90% complete for DRR034421_2.fastq
# Approx 95% complete for DRR034421_2.fastq
# null
# null
# Analysis complete for DRR130077_1.fastq
# Analysis complete for DRR130077_2.fastq
# Started analysis of DRR130077_1.fastq
# Approx 5% complete for DRR130077_1.fastq
# Approx 10% complete for DRR130077_1.fastq
# Approx 15% complete for DRR130077_1.fastq
# Approx 20% complete for DRR130077_1.fastq
# Approx 25% complete for DRR130077_1.fastq
# Approx 30% complete for DRR130077_1.fastq
# Approx 35% complete for DRR130077_1.fastq
# Approx 40% complete for DRR130077_1.fastq
# Approx 45% complete for DRR130077_1.fastq
# Approx 50% complete for DRR130077_1.fastq
# Approx 55% complete for DRR130077_1.fastq
# Approx 60% complete for DRR130077_1.fastq
# Approx 65% complete for DRR130077_1.fastq
# Approx 70% complete for DRR130077_1.fastq
# Approx 75% complete for DRR130077_1.fastq
# Approx 80% complete for DRR130077_1.fastq
# Approx 85% complete for DRR130077_1.fastq
# Approx 90% complete for DRR130077_1.fastq
# Approx 95% complete for DRR130077_1.fastq
# Started analysis of DRR130077_2.fastq
# Approx 5% complete for DRR130077_2.fastq
# Approx 10% complete for DRR130077_2.fastq
# Approx 15% complete for DRR130077_2.fastq
# Approx 20% complete for DRR130077_2.fastq
# Approx 25% complete for DRR130077_2.fastq
# Approx 30% complete for DRR130077_2.fastq
# Approx 35% complete for DRR130077_2.fastq
# Approx 40% complete for DRR130077_2.fastq
# Approx 45% complete for DRR130077_2.fastq
# Approx 50% complete for DRR130077_2.fastq
# Approx 55% complete for DRR130077_2.fastq
# Approx 60% complete for DRR130077_2.fastq
# Approx 65% complete for DRR130077_2.fastq
# Approx 70% complete for DRR130077_2.fastq
# Approx 75% complete for DRR130077_2.fastq
# Approx 80% complete for DRR130077_2.fastq
# Approx 85% complete for DRR130077_2.fastq
# Approx 90% complete for DRR130077_2.fastq
# Approx 95% complete for DRR130077_2.fastq
# null
# null
# Analysis complete for DRR130078_1.fastq
# Analysis complete for DRR130078_2.fastq
# Started analysis of DRR130078_1.fastq
# Approx 5% complete for DRR130078_1.fastq
# Approx 10% complete for DRR130078_1.fastq
# Approx 15% complete for DRR130078_1.fastq
# Approx 20% complete for DRR130078_1.fastq
# Approx 25% complete for DRR130078_1.fastq
# Approx 30% complete for DRR130078_1.fastq
# Approx 35% complete for DRR130078_1.fastq
# Approx 40% complete for DRR130078_1.fastq
# Approx 45% complete for DRR130078_1.fastq
# Approx 50% complete for DRR130078_1.fastq
# Approx 55% complete for DRR130078_1.fastq
# Approx 60% complete for DRR130078_1.fastq
# Approx 65% complete for DRR130078_1.fastq
# Approx 70% complete for DRR130078_1.fastq
# Approx 75% complete for DRR130078_1.fastq
# Approx 80% complete for DRR130078_1.fastq
# Approx 85% complete for DRR130078_1.fastq
# Approx 90% complete for DRR130078_1.fastq
# Approx 95% complete for DRR130078_1.fastq
# Started analysis of DRR130078_2.fastq
# Approx 5% complete for DRR130078_2.fastq
# Approx 10% complete for DRR130078_2.fastq
# Approx 15% complete for DRR130078_2.fastq
# Approx 20% complete for DRR130078_2.fastq
# Approx 25% complete for DRR130078_2.fastq
# Approx 30% complete for DRR130078_2.fastq
# Approx 35% complete for DRR130078_2.fastq
# Approx 40% complete for DRR130078_2.fastq
# Approx 45% complete for DRR130078_2.fastq
# Approx 50% complete for DRR130078_2.fastq
# Approx 55% complete for DRR130078_2.fastq
# Approx 60% complete for DRR130078_2.fastq
# Approx 65% complete for DRR130078_2.fastq
# Approx 70% complete for DRR130078_2.fastq
# Approx 75% complete for DRR130078_2.fastq
# Approx 80% complete for DRR130078_2.fastq
# Approx 85% complete for DRR130078_2.fastq
# Approx 90% complete for DRR130078_2.fastq
# Approx 95% complete for DRR130078_2.fastq
# null
# null
# Analysis complete for DRR130093_1.fastq
# Analysis complete for DRR130093_2.fastq
# Started analysis of DRR130093_1.fastq
# Approx 5% complete for DRR130093_1.fastq
# Approx 10% complete for DRR130093_1.fastq
# Approx 15% complete for DRR130093_1.fastq
# Approx 20% complete for DRR130093_1.fastq
# Approx 25% complete for DRR130093_1.fastq
# Approx 30% complete for DRR130093_1.fastq
# Approx 35% complete for DRR130093_1.fastq
# Approx 40% complete for DRR130093_1.fastq
# Approx 45% complete for DRR130093_1.fastq
# Approx 50% complete for DRR130093_1.fastq
# Approx 55% complete for DRR130093_1.fastq
# Approx 60% complete for DRR130093_1.fastq
# Approx 65% complete for DRR130093_1.fastq
# Approx 70% complete for DRR130093_1.fastq
# Approx 75% complete for DRR130093_1.fastq
# Approx 80% complete for DRR130093_1.fastq
# Approx 85% complete for DRR130093_1.fastq
# Approx 90% complete for DRR130093_1.fastq
# Approx 95% complete for DRR130093_1.fastq
# Started analysis of DRR130093_2.fastq
# Approx 5% complete for DRR130093_2.fastq
# Approx 10% complete for DRR130093_2.fastq
# Approx 15% complete for DRR130093_2.fastq
# Approx 20% complete for DRR130093_2.fastq
# Approx 25% complete for DRR130093_2.fastq
# Approx 30% complete for DRR130093_2.fastq
# Approx 35% complete for DRR130093_2.fastq
# Approx 40% complete for DRR130093_2.fastq
# Approx 45% complete for DRR130093_2.fastq
# Approx 50% complete for DRR130093_2.fastq
# Approx 55% complete for DRR130093_2.fastq
# Approx 60% complete for DRR130093_2.fastq
# Approx 65% complete for DRR130093_2.fastq
# Approx 70% complete for DRR130093_2.fastq
# Approx 75% complete for DRR130093_2.fastq
# Approx 80% complete for DRR130093_2.fastq
# Approx 85% complete for DRR130093_2.fastq
# Approx 90% complete for DRR130093_2.fastq
# Approx 95% complete for DRR130093_2.fastq

# %%
trimming_bbduk () {
  echo 'Read trimming with BBDuk'
  local sample_file="$1"
  sed -i 's/\r$//' "$sample_file"  

  if [ ! -f "$sample_file" ]; then
      echo "Sample '$sample_file' file not found."
      return 1
  fi

  cat "$sample_file" | xargs -I {} -P "$(nproc)" bash -c '
    sample={};
    echo "Sample: $sample";
    if [ -d "$HOME/Projeto_Mtb/Sample_reads/$sample" ]; then
      if [ -f "$HOME/Projeto_Mtb/Sample_reads/$sample/${sample}_1.fastq" ] && [ -f "$HOME/Projeto_Mtb/Sample_reads/$sample/${sample}_2.fastq" ]; then
        bbduk.sh \
          in1="$HOME/Projeto_Mtb/Sample_reads/$sample/${sample}_1.fastq" in2="$HOME/Projeto_Mtb/Sample_reads/$sample/${sample}_2.fastq" \
          out="$HOME/Projeto_Mtb/Sample_reads/$sample/${sample}_R1_bbduk.fastq" out2="$HOME/Projeto_Mtb/Sample_reads/$sample/${sample}_R2_bbduk.fastq" \
          overwrite=t \
          ref=~/Projeto_Mtb/NGS_helper_files/adapters_combined_256_unique.fasta \
          ftm=5 \
          ktrim=r k=19 mink=8 editdistance=1 editdistance2=1 \
          trimpairsevenly=f removeifeitherbad=t \
          qtrim=r trimq=20 \
          trimpolygright=10 \
          minavgquality=20 \
          minlength=20 ottm=t \
          rename=t ziplevel=1 showspeed=t ;
        rm "$HOME/Projeto_Mtb/Sample_reads/$sample/${sample}"_[1-2].fastq ; 
        echo "Trimming for $sample completed"
      else
        echo "FASTQ not found for: $sample.";
      fi
    else
      echo "Directory for $sample not found.";
    fi
  '
}

# %%
trimming_bbduk ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Read trimming with BBDuk
# Sample: DRR130077
# Sample: DRR130078
# Sample: DRR034421
# Sample: DRR130093
# /usr/share/bbmap/calcmem.sh: line 207: dpkg-architecture: command not found
# /usr/share/bbmap/calcmem.sh: line 207: dpkg-architecture: command not found
# /usr/share/bbmap/calcmem.sh: line 207: dpkg-architecture: command not found
# /usr/share/bbmap/calcmem.sh: line 207: dpkg-architecture: command not found
# java -ea -Xmx283m -Xms283m -cp /usr/share/java/bbmap.jar jgi.BBDuk in1=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_1.fastq in2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_2.fastq out=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_R1_bbduk.fastq out2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_R2_bbduk.fastq overwrite=t ref=/home/ritanobrega00/Projeto_Mtb/NGS_helper_files/adapters_combined_256_unique.fasta ftm=5 ktrim=r k=19 mink=8 editdistance=1 editdistance2=1 trimpairsevenly=f removeifeitherbad=t qtrim=r trimq=20 trimpolygright=10 minavgquality=20 minlength=20 ottm=t rename=t ziplevel=1 showspeed=t
# java -ea -Xmx283m -Xms283m -cp /usr/share/java/bbmap.jar jgi.BBDuk in1=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_1.fastq in2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_2.fastq out=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_R1_bbduk.fastq out2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_R2_bbduk.fastq overwrite=t ref=/home/ritanobrega00/Projeto_Mtb/NGS_helper_files/adapters_combined_256_unique.fasta ftm=5 ktrim=r k=19 mink=8 editdistance=1 editdistance2=1 trimpairsevenly=f removeifeitherbad=t qtrim=r trimq=20 trimpolygright=10 minavgquality=20 minlength=20 ottm=t rename=t ziplevel=1 showspeed=t
# java -ea -Xmx285m -Xms285m -cp /usr/share/java/bbmap.jar jgi.BBDuk in1=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_1.fastq in2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_2.fastq out=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_R1_bbduk.fastq out2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_R2_bbduk.fastq overwrite=t ref=/home/ritanobrega00/Projeto_Mtb/NGS_helper_files/adapters_combined_256_unique.fasta ftm=5 ktrim=r k=19 mink=8 editdistance=1 editdistance2=1 trimpairsevenly=f removeifeitherbad=t qtrim=r trimq=20 trimpolygright=10 minavgquality=20 minlength=20 ottm=t rename=t ziplevel=1 showspeed=t
# java -ea -Xmx285m -Xms285m -cp /usr/share/java/bbmap.jar jgi.BBDuk in1=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_1.fastq in2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_2.fastq out=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_R1_bbduk.fastq out2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_R2_bbduk.fastq overwrite=t ref=/home/ritanobrega00/Projeto_Mtb/NGS_helper_files/adapters_combined_256_unique.fasta ftm=5 ktrim=r k=19 mink=8 editdistance=1 editdistance2=1 trimpairsevenly=f removeifeitherbad=t qtrim=r trimq=20 trimpolygright=10 minavgquality=20 minlength=20 ottm=t rename=t ziplevel=1 showspeed=t
# Executing jgi.BBDuk [in1=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_1.fastq, in2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_2.fastq, out=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_R1_bbduk.fastq, out2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_R2_bbduk.fastq, overwrite=t, ref=/home/ritanobrega00/Projeto_Mtb/NGS_helper_files/adapters_combined_256_unique.fasta, ftm=5, ktrim=r, k=19, mink=8, editdistance=1, editdistance2=1, trimpairsevenly=f, removeifeitherbad=t, qtrim=r, trimq=20, trimpolygright=10, minavgquality=20, minlength=20, ottm=t, rename=t, ziplevel=1, showspeed=t]Executing jgi.BBDuk [in1=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_1.fastq, in2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_2.fastq, out=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_R1_bbduk.fastq, out2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_R2_bbduk.fastq, overwrite=t, ref=/home/ritanobrega00/Projeto_Mtb/NGS_helper_files/adapters_combined_256_unique.fasta, ftm=5, ktrim=r, k=19, mink=8, editdistance=1, editdistance2=1, trimpairsevenly=f, removeifeitherbad=t, qtrim=r, trimq=20, trimpolygright=10, minavgquality=20, minlength=20, ottm=t, rename=t, ziplevel=1, showspeed=t]
#
# Version 38.95Version 38.95Executing jgi.BBDuk [in1=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_1.fastq, in2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_2.fastq, out=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_R1_bbduk.fastq, out2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_R2_bbduk.fastq, overwrite=t, ref=/home/ritanobrega00/Projeto_Mtb/NGS_helper_files/adapters_combined_256_unique.fasta, ftm=5, ktrim=r, k=19, mink=8, editdistance=1, editdistance2=1, trimpairsevenly=f, removeifeitherbad=t, qtrim=r, trimq=20, trimpolygright=10, minavgquality=20, minlength=20, ottm=t, rename=t, ziplevel=1, showspeed=t]
#
#
#
#
# Version 38.95
#
# Executing jgi.BBDuk [in1=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_1.fastq, in2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_2.fastq, out=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_R1_bbduk.fastq, out2=/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_R2_bbduk.fastq, overwrite=t, ref=/home/ritanobrega00/Projeto_Mtb/NGS_helper_files/adapters_combined_256_unique.fasta, ftm=5, ktrim=r, k=19, mink=8, editdistance=1, editdistance2=1, trimpairsevenly=f, removeifeitherbad=t, qtrim=r, trimq=20, trimpolygright=10, minavgquality=20, minlength=20, ottm=t, rename=t, ziplevel=1, showspeed=t]
# Version 38.95
#
# maskMiddle was disabled because useShortKmers=true
# maskMiddle was disabled because useShortKmers=true
# maskMiddle was disabled because useShortKmers=true
# maskMiddle was disabled because useShortKmers=true
# 0.060 seconds.
# 0.067 seconds.Initial:
#
# Memory: max=297m, total=297m, free=279m, used=18m
# Initial:
#
# Memory: max=297m, total=297m, free=279m, used=18m
#
# 0.057 seconds.0.056 seconds.
#
# Initial:Initial:
#
# Memory: max=299m, total=299m, free=281m, used=18mMemory: max=299m, total=299m, free=281m, used=18m
#
#
#
# Added 380322 kmers; time: 	0.984 seconds.
# Memory: max=299m, total=299m, free=278m, used=21m
#
# Input is being processed as paired
# Added 380322 kmers; time: 	0.990 seconds.
# Memory: max=299m, total=299m, free=278m, used=21m
#
# Input is being processed as paired
# Added 380322 kmers; time: 	0.997 seconds.
# Memory: max=297m, total=297m, free=276m, used=21m
#
# Input is being processed as paired
# Added 380322 kmers; time: 	1.023 seconds.
# Memory: max=297m, total=297m, free=276m, used=21m
#
# Started output streams:	0.052 seconds.
# Started output streams:	0.073 seconds.
# Input is being processed as paired
# Started output streams:	0.082 seconds.
# Started output streams:	0.199 seconds.
# Processing time:   		67.546 seconds.
#
# Input:                  	1212518 reads 		304753833 bases.
# QTrimmed:               	926237 reads (76.39%) 	100246514 bases (32.89%)
# Polymer-trimmed:        	22 reads (0.00%) 	240 bases (0.00%)
# FTrimmed:               	944697 reads (77.91%) 	1681978 bases (0.55%)
# KTrimmed:               	182800 reads (15.08%) 	4981126 bases (1.63%)
# Low quality discards:   	77106 reads (6.36%) 	8317898 bases (2.73%)
# Total Removed:          	95148 reads (7.85%) 	115227756 bases (37.81%)
# Result:                 	1117370 reads (92.15%) 	189526077 bases (62.19%)
#
# Time:                         	68.790 seconds.
# Reads Processed:       1212k 	17.63k reads/sec
# Bases Processed:        304m 	4.43m bases/sec
# Trimming for DRR034421 completed
# Processing time:   		72.361 seconds.
#
# Input:                  	1147940 reads 		335422522 bases.
# QTrimmed:               	1053575 reads (91.78%) 	93415295 bases (27.85%)
# Polymer-trimmed:        	146 reads (0.01%) 	1858 bases (0.00%)
# FTrimmed:               	287828 reads (25.07%) 	1000277 bases (0.30%)
# KTrimmed:               	163951 reads (14.28%) 	13551186 bases (4.04%)
# Low quality discards:   	32862 reads (2.86%) 	3689640 bases (1.10%)
# Total Removed:          	79388 reads (6.92%) 	111658256 bases (33.29%)
# Result:                 	1068552 reads (93.08%) 	223764266 bases (66.71%)
#
# Time:                         	73.447 seconds.
# Reads Processed:       1147k 	15.63k reads/sec
# Bases Processed:        335m 	4.57m bases/sec
# Trimming for DRR130077 completed
# Processing time:   		85.569 seconds.
#
# Input:                  	1727074 reads 		497995063 bases.
# QTrimmed:               	1421317 reads (82.30%) 	68619895 bases (13.78%)
# Polymer-trimmed:        	117 reads (0.01%) 	1384 bases (0.00%)
# FTrimmed:               	450461 reads (26.08%) 	1448788 bases (0.29%)
# KTrimmed:               	220847 reads (12.79%) 	7707993 bases (1.55%)
# Low quality discards:   	30334 reads (1.76%) 	3792020 bases (0.76%)
# Total Removed:          	56582 reads (3.28%) 	81570080 bases (16.38%)
# Result:                 	1670492 reads (96.72%) 	416424983 bases (83.62%)
#
# Time:                         	86.650 seconds.
# Reads Processed:       1727k 	19.93k reads/sec
# Bases Processed:        497m 	5.75m bases/sec
# Trimming for DRR130078 completed
# Processing time:   		98.712 seconds.
#
# Input:                  	2736154 reads 		795534093 bases.
# QTrimmed:               	2335328 reads (85.35%) 	135818388 bases (17.07%)
# Polymer-trimmed:        	271 reads (0.01%) 	3335 bases (0.00%)
# FTrimmed:               	691445 reads (25.27%) 	2133908 bases (0.27%)
# KTrimmed:               	325677 reads (11.90%) 	4310091 bases (0.54%)
# Low quality discards:   	74454 reads (2.72%) 	9408039 bases (1.18%)
# Total Removed:          	89050 reads (3.25%) 	151673761 bases (19.07%)
# Result:                 	2647104 reads (96.75%) 	643860332 bases (80.93%)
#
# Time:                         	99.767 seconds.
# Reads Processed:       2736k 	27.43k reads/sec
# Bases Processed:        795m 	7.97m bases/sec
# Trimming for DRR130093 completed

# %% [markdown]
# # **3. Mapping**
#
# After the pre-processement to ensure we will only work with high-quality reads, the trimmed reads will be mapped against the *Mtb*'s ancestral reference genome.
#
# The function `map_bwa` uses the `bwa mem` [3] and `samtools` to perform the mapping and consequent creation of the BAM file per sample, which will be indexed, sorted by read name, and compressed, to facilitate efficient access and retrieval of read alignments.

# %%
map_bwa() {
  echo "Mapping genomes to MTB_anc with bwa mem + sorting BAM by read name"
  
  local sample_file="$1"
  local genome_reference="$HOME/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta"
  local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads"

  if [ ! -f "$sample_file" ]; then
      echo "Sample '$sample_file' file not found."
      return 1
  fi

  while IFS= read -r sample; do
    echo -e "\nMapping Sample: $sample"
    
    if [ ! -f "$sra_diretoria/$sample/${sample}_R1_bbduk.fastq" ] || [ ! -f "$sra_diretoria/$sample/${sample}_R2_bbduk.fastq" ]; then
      echo "Input for '$sample_file' not found."
      continue
    fi

    bwa_threads=$(nproc)
    bwa mem -t "$bwa_threads" "$genome_reference" "$sra_diretoria/$sample/${sample}_R1_bbduk.fastq" "$sra_diretoria/$sample/${sample}_R2_bbduk.fastq" \
    | samtools sort -n -l 1 -@ 1 -o "$sra_diretoria/$sample/$sample.bam"

    samtools view -@ 1 -b "$sra_diretoria/$sample/$sample.bam" | samtools sort -@ 1 -o "$sra_diretoria/$sample/${sample}_sorted.bam"
    samtools index -@ 1 "$sra_diretoria/$sample/${sample}_sorted.bam"
    
    rm "$sra_diretoria/$sample/${sample}_R1_bbduk.fastq" "$sra_diretoria/$sample/${sample}_R2_bbduk.fastq"

    echo "Mapping for $sample completed."
  done < "$sample_file"
}

# %%
map_bwa ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Mapping genomes to MTB_anc with bwa mem + sorting BAM by read name
#
# Mapping Sample: DRR034421
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 461778 sequences (80000283 bp)...
# [M::process] read 476458 sequences (80000462 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (843, 221806, 87, 561)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (117, 200, 357)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 837)
# [M::mem_pestat] mean and std.dev: (242.04, 171.94)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1077)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (178, 266, 389)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 811)
# [M::mem_pestat] mean and std.dev: (294.03, 155.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1022)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (185, 641, 1765)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 4925)
# [M::mem_pestat] mean and std.dev: (1091.02, 1104.03)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 6505)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (125, 228, 391)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 923)
# [M::mem_pestat] mean and std.dev: (263.61, 188.51)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1189)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 461778 reads in 107.856 CPU sec, 15.043 real sec
# [M::process] read 179134 sequences (29525332 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (1035, 227996, 89, 573)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (142, 234, 389)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 883)
# [M::mem_pestat] mean and std.dev: (274.60, 182.07)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1130)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (189, 277, 401)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 825)
# [M::mem_pestat] mean and std.dev: (305.47, 157.17)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1037)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (310, 805, 2148)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 5824)
# [M::mem_pestat] mean and std.dev: (1225.48, 1110.98)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 7662)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (147, 234, 448)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1050)
# [M::mem_pestat] mean and std.dev: (282.26, 197.37)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1351)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 476458 reads in 103.725 CPU sec, 13.723 real sec
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (381, 85610, 49, 232)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (147, 238, 406)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 924)
# [M::mem_pestat] mean and std.dev: (283.48, 185.30)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1183)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (204, 294, 423)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 861)
# [M::mem_pestat] mean and std.dev: (324.75, 162.26)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1080)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (231, 773, 1808)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 4962)
# [M::mem_pestat] mean and std.dev: (1089.82, 1061.94)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 6539)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (166, 251, 405)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 883)
# [M::mem_pestat] mean and std.dev: (278.08, 166.53)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1122)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 179134 reads in 42.247 CPU sec, 5.772 real sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -t 8 /home/ritanobrega00/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_R1_bbduk.fastq /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_R2_bbduk.fastq
# [main] Real time: 37.049 sec; CPU: 255.750 sec
# Mapping for DRR034421 completed.
#
# Mapping Sample: DRR130077
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 390894 sequences (80000342 bp)...
# [M::process] read 381678 sequences (80000403 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (581, 185285, 90, 520)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (241, 303, 380)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 658)
# [M::mem_pestat] mean and std.dev: (303.31, 99.63)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 797)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (383, 426, 477)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (195, 665)
# [M::mem_pestat] mean and std.dev: (428.43, 75.37)
# [M::mem_pestat] low and high boundaries for proper pairs: (101, 759)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (690, 1837, 2430)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 5910)
# [M::mem_pestat] mean and std.dev: (1723.08, 1260.99)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 7650)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (200, 272, 360)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 680)
# [M::mem_pestat] mean and std.dev: (272.41, 110.36)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 840)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 390894 reads in 185.388 CPU sec, 31.614 real sec
# [M::process] read 295980 sequences (63763521 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (578, 181153, 67, 475)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (227, 304, 385)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 701)
# [M::mem_pestat] mean and std.dev: (302.69, 113.78)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 859)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (384, 428, 480)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (192, 672)
# [M::mem_pestat] mean and std.dev: (430.06, 76.26)
# [M::mem_pestat] low and high boundaries for proper pairs: (96, 768)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (1250, 1968, 2524)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 5072)
# [M::mem_pestat] mean and std.dev: (1763.23, 1055.72)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 6346)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (201, 270, 351)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 651)
# [M::mem_pestat] mean and std.dev: (273.69, 108.11)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 801)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 381678 reads in 163.378 CPU sec, 22.446 real sec
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (436, 140655, 50, 336)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (235, 303, 366)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 628)
# [M::mem_pestat] mean and std.dev: (296.24, 104.49)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 759)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (385, 429, 482)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (191, 676)
# [M::mem_pestat] mean and std.dev: (431.08, 76.48)
# [M::mem_pestat] low and high boundaries for proper pairs: (94, 773)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (810, 1617, 2370)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 5490)
# [M::mem_pestat] mean and std.dev: (1627.44, 1177.75)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 7050)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (200, 272, 377)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 731)
# [M::mem_pestat] mean and std.dev: (278.66, 121.49)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 908)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 295980 reads in 162.043 CPU sec, 24.860 real sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -t 8 /home/ritanobrega00/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_R1_bbduk.fastq /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_R2_bbduk.fastq
# [main] Real time: 113.816 sec; CPU: 539.470 sec
# Mapping for DRR130077 completed.
#
# Mapping Sample: DRR130078
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 324350 sequences (80000298 bp)...
# [M::process] read 323674 sequences (80000401 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (279, 156271, 31, 185)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 236, 293)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 493)
# [M::mem_pestat] mean and std.dev: (239.90, 74.19)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 593)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (347, 377, 411)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (219, 539)
# [M::mem_pestat] mean and std.dev: (378.48, 48.99)
# [M::mem_pestat] low and high boundaries for proper pairs: (155, 603)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (1294, 1559, 2434)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 4714)
# [M::mem_pestat] mean and std.dev: (1555.21, 919.47)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 5854)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (150, 203, 245)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 435)
# [M::mem_pestat] mean and std.dev: (192.25, 69.92)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 530)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 324350 reads in 225.708 CPU sec, 32.863 real sec
# [M::process] read 320878 sequences (80000165 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (337, 156061, 34, 227)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (201, 251, 306)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 516)
# [M::mem_pestat] mean and std.dev: (248.87, 72.22)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 621)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (347, 377, 411)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (219, 539)
# [M::mem_pestat] mean and std.dev: (378.32, 48.83)
# [M::mem_pestat] low and high boundaries for proper pairs: (155, 603)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (493, 1396, 2222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 5680)
# [M::mem_pestat] mean and std.dev: (1355.18, 951.40)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 7409)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (152, 203, 273)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 515)
# [M::mem_pestat] mean and std.dev: (209.72, 89.46)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 636)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 323674 reads in 230.522 CPU sec, 32.329 real sec
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (298, 154697, 41, 222)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (203, 250, 304)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 506)
# [M::mem_pestat] mean and std.dev: (249.56, 76.35)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 607)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (347, 377, 411)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (219, 539)
# [M::mem_pestat] mean and std.dev: (378.71, 48.69)
# [M::mem_pestat] low and high boundaries for proper pairs: (155, 603)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (169, 1289, 2370)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 6772)
# [M::mem_pestat] mean and std.dev: (1471.00, 1537.05)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 8973)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (157, 203, 263)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 475)
# [M::mem_pestat] mean and std.dev: (203.73, 70.76)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 581)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 320878 reads in 246.114 CPU sec, 47.606 real sec
# [M::process] read 318832 sequences (80000083 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (284, 153717, 47, 208)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (196, 240, 292)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (4, 484)
# [M::mem_pestat] mean and std.dev: (238.30, 73.36)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 580)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (348, 377, 412)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (220, 540)
# [M::mem_pestat] mean and std.dev: (379.04, 48.49)
# [M::mem_pestat] low and high boundaries for proper pairs: (156, 604)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (415, 914, 1664)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 4162)
# [M::mem_pestat] mean and std.dev: (1138.83, 938.50)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 5411)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (162, 215, 280)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 516)
# [M::mem_pestat] mean and std.dev: (215.57, 85.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 634)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 318832 reads in 225.924 CPU sec, 32.439 real sec
# [M::process] read 318064 sequences (80000368 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (293, 153329, 46, 202)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (204, 246, 299)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (14, 489)
# [M::mem_pestat] mean and std.dev: (243.66, 72.92)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 584)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (348, 377, 412)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (220, 540)
# [M::mem_pestat] mean and std.dev: (378.97, 48.69)
# [M::mem_pestat] low and high boundaries for proper pairs: (156, 604)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (425, 1396, 2153)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 5609)
# [M::mem_pestat] mean and std.dev: (1253.67, 974.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 7337)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (162, 202, 261)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 459)
# [M::mem_pestat] mean and std.dev: (205.38, 74.99)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 558)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 318064 reads in 205.055 CPU sec, 32.199 real sec
# [M::process] read 64694 sequences (16423668 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (61, 31190, 12, 32)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (180, 236, 294)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 522)
# [M::mem_pestat] mean and std.dev: (239.67, 69.47)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 636)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (349, 378, 413)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (221, 541)
# [M::mem_pestat] mean and std.dev: (379.35, 48.71)
# [M::mem_pestat] low and high boundaries for proper pairs: (157, 605)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (1635, 2215, 3203)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 6339)
# [M::mem_pestat] mean and std.dev: (2064.64, 1259.72)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 7907)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (168, 223, 315)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 609)
# [M::mem_pestat] mean and std.dev: (207.77, 91.28)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 756)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 64694 reads in 26.025 CPU sec, 3.878 real sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -t 8 /home/ritanobrega00/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_R1_bbduk.fastq /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_R2_bbduk.fastq
# [main] Real time: 256.137 sec; CPU: 1184.592 sec
# [bam_sort_core] merging from 1 files and 1 in-memory blocks...
# [bam_sort_core] merging from 1 files and 1 in-memory blocks...
# Mapping for DRR130078 completed.
#
# Mapping Sample: DRR130093
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 352688 sequences (80000082 bp)...
# [M::process] read 346144 sequences (80000239 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (374, 167792, 38, 281)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (216, 270, 329)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 555)
# [M::mem_pestat] mean and std.dev: (265.07, 76.33)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 668)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (371, 396, 425)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (263, 533)
# [M::mem_pestat] mean and std.dev: (400.13, 41.19)
# [M::mem_pestat] low and high boundaries for proper pairs: (209, 587)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (913, 1636, 2492)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 5650)
# [M::mem_pestat] mean and std.dev: (1864.24, 1286.96)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 7229)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (179, 223, 278)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 476)
# [M::mem_pestat] mean and std.dev: (220.40, 70.44)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 575)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 352688 reads in 120.288 CPU sec, 17.162 real sec
# [M::process] read 325702 sequences (80000300 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (360, 164822, 38, 254)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (216, 273, 322)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (4, 534)
# [M::mem_pestat] mean and std.dev: (267.47, 75.84)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 640)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (371, 396, 425)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (263, 533)
# [M::mem_pestat] mean and std.dev: (400.23, 40.95)
# [M::mem_pestat] low and high boundaries for proper pairs: (209, 587)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (1509, 2207, 2499)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 4479)
# [M::mem_pestat] mean and std.dev: (1908.40, 911.77)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 5555)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (161, 217, 263)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 467)
# [M::mem_pestat] mean and std.dev: (211.06, 72.30)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 569)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 346144 reads in 113.530 CPU sec, 15.014 real sec
# [M::process] read 326172 sequences (80000341 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (268, 156529, 36, 215)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (188, 229, 278)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (8, 458)
# [M::mem_pestat] mean and std.dev: (234.46, 65.61)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 548)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (331, 358, 388)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (217, 502)
# [M::mem_pestat] mean and std.dev: (360.21, 42.36)
# [M::mem_pestat] low and high boundaries for proper pairs: (160, 559)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (349, 2196, 2523)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 6871)
# [M::mem_pestat] mean and std.dev: (1743.43, 1444.48)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 9045)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (149, 194, 265)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 497)
# [M::mem_pestat] mean and std.dev: (198.95, 77.22)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 613)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 325702 reads in 100.648 CPU sec, 13.198 real sec
# [M::process] read 318534 sequences (80000384 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (283, 156843, 27, 193)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (180, 235, 293)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 519)
# [M::mem_pestat] mean and std.dev: (234.65, 75.42)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 632)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (330, 355, 383)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (224, 489)
# [M::mem_pestat] mean and std.dev: (357.11, 39.35)
# [M::mem_pestat] low and high boundaries for proper pairs: (171, 542)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (1348, 2125, 2430)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 4594)
# [M::mem_pestat] mean and std.dev: (1688.23, 821.47)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 5676)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (145, 189, 258)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 484)
# [M::mem_pestat] mean and std.dev: (200.62, 78.81)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 597)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 326172 reads in 107.497 CPU sec, 14.106 real sec
# [M::process] read 323180 sequences (80000173 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (229, 153426, 29, 182)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (188, 221, 286)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 482)
# [M::mem_pestat] mean and std.dev: (227.58, 61.33)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 580)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (330, 355, 384)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (222, 492)
# [M::mem_pestat] mean and std.dev: (357.28, 39.69)
# [M::mem_pestat] low and high boundaries for proper pairs: (168, 546)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (886, 2182, 2904)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 6940)
# [M::mem_pestat] mean and std.dev: (1907.83, 1318.60)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 8958)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (151, 197, 253)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 457)
# [M::mem_pestat] mean and std.dev: (194.23, 66.52)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 559)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 318534 reads in 116.585 CPU sec, 15.850 real sec
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (253, 155523, 17, 199)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (191, 236, 287)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 479)
# [M::mem_pestat] mean and std.dev: (235.12, 70.46)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 575)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (330, 355, 384)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (222, 492)
# [M::mem_pestat] mean and std.dev: (357.37, 39.75)
# [M::mem_pestat] low and high boundaries for proper pairs: (168, 546)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (738, 1389, 2499)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 6021)
# [M::mem_pestat] mean and std.dev: (1574.82, 928.23)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 7782)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (148, 183, 226)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 382)
# [M::mem_pestat] mean and std.dev: (186.29, 62.33)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 460)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 323180 reads in 118.121 CPU sec, 17.413 real sec
# [M::process] read 323400 sequences (80000298 bp)...
# [M::process] read 316230 sequences (80000046 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (289, 155600, 22, 201)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (190, 233, 291)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 493)
# [M::mem_pestat] mean and std.dev: (235.07, 66.56)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 594)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (330, 355, 384)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (222, 492)
# [M::mem_pestat] mean and std.dev: (357.20, 39.68)
# [M::mem_pestat] low and high boundaries for proper pairs: (168, 546)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (921, 1325, 2253)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 4917)
# [M::mem_pestat] mean and std.dev: (1371.90, 808.84)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 6249)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (141, 188, 239)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 435)
# [M::mem_pestat] mean and std.dev: (188.30, 68.92)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 533)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 323400 reads in 98.707 CPU sec, 12.775 real sec
# [M::process] read 15054 sequences (3858469 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (246, 152364, 23, 184)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (188, 231, 284)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 476)
# [M::mem_pestat] mean and std.dev: (229.85, 70.52)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 572)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (331, 356, 384)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (225, 490)
# [M::mem_pestat] mean and std.dev: (357.69, 39.02)
# [M::mem_pestat] low and high boundaries for proper pairs: (172, 543)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (857, 1313, 2238)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 5000)
# [M::mem_pestat] mean and std.dev: (1326.96, 745.54)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 6381)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (139, 185, 242)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 448)
# [M::mem_pestat] mean and std.dev: (187.61, 76.22)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 551)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 316230 reads in 108.064 CPU sec, 14.139 real sec
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (15, 7257, 1, 6)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (212, 256, 297)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (42, 467)
# [M::mem_pestat] mean and std.dev: (248.64, 50.84)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 552)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (331, 356, 384)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (225, 490)
# [M::mem_pestat] mean and std.dev: (357.00, 39.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (172, 543)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation FF
# [M::mem_process_seqs] Processed 15054 reads in 5.126 CPU sec, 0.724 real sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -t 8 /home/ritanobrega00/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_R1_bbduk.fastq /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_R2_bbduk.fastq
# [main] Real time: 140.859 sec; CPU: 892.638 sec
# [bam_sort_core] merging from 1 files and 1 in-memory blocks...
# [bam_sort_core] merging from 1 files and 1 in-memory blocks...
# Mapping for DRR130093 completed.

# %% [markdown]
# # **4. Post-Processing**
#
# After mapping, mapped reads will be post-processed to ensure the reliability of the subsequent analysis (variant calling).
#
# First, duplicates will be marked using `samtools markup` in the function `mark_duplicates`, and the BAM files will be indexed.
#
# Then, for each of these BAM files, coverage will be calculated using `mosdepth` [4] to provide a measure of the depth of sequencing across the genome. In the function `calculate_bam_coverage`, only properly paired and mapped reads will be included in the coverage calculation. Moreover, only reads with a mapping quality of at least 20 will be included (the median will be used instead of the mean) and, for each sample, 4 files will be created: summary; golbal.dist; per-base.bed (zip and csi file).
#
# After obtaining BAM coverage, the function `process_coverage_metrics` will extract and store (in a file) the coverage metrics, as well as remove and store the regions with no coverage.

# %%
# Duplicates marking 
mark_duplicates() {
  echo "Marking duplicates with samtools markdup and indexing BAM files"
  local sample_file="$1"
  local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads"
  local threads=$(nproc)

  if [ ! -f "$sample_file" ]; then
    echo "Sample '$sample_file' file not found."
    return 1
  fi

  while IFS= read -r sample || [[ -n $sample ]]; do
    if [ ! -f "$sra_diretoria/$sample/$sample.bam" ]; then
      echo "No BAM file found for: $sample."
      continue
    fi

    samtools fixmate -m -@ 2 "$sra_diretoria/$sample/$sample.bam" -u - \
    | samtools sort -u -@ 2 - \
    | samtools markdup --include-fails -S --mode s -@ 2 - -O bam,level=1 "$sra_diretoria/$sample/${sample}_markdup.bam" \
    && samtools index -@ 2 "$sra_diretoria/$sample/${sample}_markdup.bam" \
    && rm "$sra_diretoria/$sample/$sample.bam"

  done < "$sample_file"

  echo "Duplicate marking and indexing finished"
}

# %%
mark_duplicates ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Marking duplicates with samtools markdup and indexing BAM files
# [bam_sort_core] merging from 0 files and 2 in-memory blocks...
# [bam_sort_core] merging from 0 files and 2 in-memory blocks...
# [bam_sort_core] merging from 0 files and 2 in-memory blocks...
# [bam_sort_core] merging from 0 files and 2 in-memory blocks...
# Duplicate marking and indexing finished

# %%
calculate_bam_coverage() {
  local sample_file="$1"
  local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads"
  local threads=$(nproc)
  local mosdepth_bin="$CONDA_PREFIX/bin/mosdepth"

  echo "Calculating bam coverage with mosdepth in parallel"
  while IFS= read -r sample || [[ -n $sample ]]; do
    if [ -z "$sample" ]; then
      continue 
    fi

    if [ ! -d "$sra_diretoria/$sample" ]; then
      echo "Directory not found for: $sample"
      continue
    fi

    bam_file="$sra_diretoria/$sample/${sample}_markdup.bam"
    if [ ! -f "$bam_file" ]; then
      echo "No BAM found for: $sample"
      continue
    fi

    pushd "$sra_diretoria/$sample" > /dev/null || continue
    echo "Calculating coverage for ${sample}_markdup.bam"
    echo "$bam_file" | parallel -j0 --colsep="\t" "${mosdepth_bin}" --flag 3844 --mapq 20 --use-median --threads "$threads" "${sample}_markdup.bam"

    echo "BAM coverage calculated for $sample"

    popd > /dev/null || continue
  done < "$sample_file"

  echo "Coverage calculation completed"
}

# %%
calculate_bam_coverage ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Calculating bam coverage with mosdepth in parallel
# Calculating coverage for DRR034421_markdup.bam
# Academic tradition requires you to cite works you base your article on.
# When using programs that use GNU Parallel to process data for publication
# please cite:
#
#   O. Tange (2011): GNU Parallel - The Command-Line Power Tool,
#   ;login: The USENIX Magazine, February 2011:42-47.
#
# This helps funding further development; AND IT WON'T COST YOU A CENT.
# If you pay 10000 EUR you should feel free to use GNU Parallel without citing.
#
# To silence the citation notice: run 'parallel --citation'.
#
# BAM coverage calculated for DRR034421
# Calculating coverage for DRR130077_markdup.bam
# Academic tradition requires you to cite works you base your article on.
# When using programs that use GNU Parallel to process data for publication
# please cite:
#
#   O. Tange (2011): GNU Parallel - The Command-Line Power Tool,
#   ;login: The USENIX Magazine, February 2011:42-47.
#
# This helps funding further development; AND IT WON'T COST YOU A CENT.
# If you pay 10000 EUR you should feel free to use GNU Parallel without citing.
#
# To silence the citation notice: run 'parallel --citation'.
#
# BAM coverage calculated for DRR130077
# Calculating coverage for DRR130078_markdup.bam
# Academic tradition requires you to cite works you base your article on.
# When using programs that use GNU Parallel to process data for publication
# please cite:
#
#   O. Tange (2011): GNU Parallel - The Command-Line Power Tool,
#   ;login: The USENIX Magazine, February 2011:42-47.
#
# This helps funding further development; AND IT WON'T COST YOU A CENT.
# If you pay 10000 EUR you should feel free to use GNU Parallel without citing.
#
# To silence the citation notice: run 'parallel --citation'.
#
# BAM coverage calculated for DRR130078
# Calculating coverage for DRR130093_markdup.bam
# Academic tradition requires you to cite works you base your article on.
# When using programs that use GNU Parallel to process data for publication
# please cite:
#
#   O. Tange (2011): GNU Parallel - The Command-Line Power Tool,
#   ;login: The USENIX Magazine, February 2011:42-47.
#
# This helps funding further development; AND IT WON'T COST YOU A CENT.
# If you pay 10000 EUR you should feel free to use GNU Parallel without citing.
#
# To silence the citation notice: run 'parallel --citation'.
#
# BAM coverage calculated for DRR130093
# Coverage calculation completed

# %%
process_coverage_metrics() {
    local sample_file="$1"
    local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads"

    while IFS= read -r sample || [[ -n $sample ]]; do
        local summary_file="$sra_diretoria/$sample/${sample}_markdup.bam.mosdepth.summary.txt"
        local dist_file="$sra_diretoria/$sample/${sample}_markdup.bam.mosdepth.global.dist.txt"
        
        if [ ! -f "$summary_file" ] || [ ! -f "$dist_file" ]; then
            echo "Coverage metric files not found for sample $sample"
            continue
        fi

        echo "Extracting coverage metrics for $sample"
        
        local median=$(awk 'NR>1 && NR%2==1 {print $4}' "$summary_file")
        local cov10=$(grep -m1 '^10\t' "$dist_file" | awk '{print $3}')
        echo -e "$sample\t$median\t$cov10" > "$sra_diretoria/$sample/${sample}_coveragecheck.tsv"

        echo "Extracting genomic positions without mapped coverage for $sample"
        
        grep -h -E '^[^[:space:]]+[[:space:]]+0$' "$sra_diretoria/$sample/"*per-base* > "$sra_diretoria/$sample/${sample}_zerocoverageregions.tsv"

        rm -f "$sra_diretoria/$sample/"*mosdepth* "$sra_diretoria/$sample/"*per-base*
    
    done < "$sample_file" 
}

# %%
process_coverage_metrics ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Extracting coverage metrics for DRR034421
# Extracting genomic positions without mapped coverage for DRR034421
# Extracting coverage metrics for DRR130077
# Extracting genomic positions without mapped coverage for DRR130077
# Extracting coverage metrics for DRR130078
# Extracting genomic positions without mapped coverage for DRR130078
# Extracting coverage metrics for DRR130093
# Extracting genomic positions without mapped coverage for DRR130093

# %% [markdown]
# # **5. Variant Calling**
#
# The processed BAM files will be used for the variant calling to ensure the use and call of realiable data.
#
# For variant identification, different strategies were implemented to compare and integrate the information of different callers in the final result.

# %% [markdown]
# ## Simple variant calling with `bcftools mpileup`
#
# Firstly, the most simple variant calling was performed using the `bcftools mpileup` and `bcftools call` commands with no extra options in order to obtain the most basic and simple VCF file [5].

# %%
variant_calling_simple() {
    local sample_file="$1"
    local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads"
    local ref_file="$HOME/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta"
    
    while IFS= read -r sample || [[ -n $sample ]]; do
        echo "Running variant calling for sample: $sample" 
        bcftools mpileup -Ou -f "$ref_file" "$sra_diretoria/$sample/${sample}_markdup.bam" \
        | bcftools call --ploidy 1 -Ov -vc -o "$sra_diretoria/$sample/${sample}_simple.vcf"
    done < "$sample_file" 
}

# %%
variant_calling_simple ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Running variant calling for sample: DRR034421
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250
# Running variant calling for sample: DRR130077
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250
# Running variant calling for sample: DRR130078
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250
# Running variant calling for sample: DRR130093
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250

# %% [markdown]
# ## Variant Calling with Filters and Annotations using `bcftools mpileup, call, norm, annotate`
#
# The second strategy used consisted in the use of `bcftools mpileup` and `call`, as well as `norm` and `annotate` [5], to apply filters (e.g. use of reads with a quality of alignment and mapping superior to 20), normalize the representation of the variants called, and add information for each one regarding, for example, lineage, excluded regions and mapability.

# %%
create_intervals() {
    local threads=24
    local output_file="$HOME/Projeto_Mtb/NGS_helper_files/intervals_${threads}threads.bed"
    
    echo "Creating equally-sized intervals file for the reference genome"
    bedtools makewindows -g ~/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta.fai -n "$threads" -i winnum \
    | awk '{print $1"\t"$2+1"\t"$3}' > "$output_file"
    cat -n "$output_file"
}

run_variant_calling() {
    local sample="$1"
    local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads"
    local output_dir="$sra_diretoria/$sample"
    local output_prefix="${sample}_bcftools_varsonly"
    local ref_file="$HOME/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta"
    local threads=$(nproc)
    local intervals_file="$HOME/Projeto_Mtb/NGS_helper_files/intervals_24threads.bed"

    echo "Running variant calling for sample: $sample"
    bcftools mpileup -f "$ref_file" "$sra_diretoria/$sample/${sample}_markdup.bam" \
    --count-orphans \
    --no-BAQ --min-MQ 20 --min-BQ 20 \
    --regions-file "$intervals_file" \
    --annotate AD,ADF,ADR,DP,SP,SCR,INFO/AD,INFO/ADF,INFO/ADR,INFO/SCR \
    --threads "$threads" --output-type u \
    | bcftools call --ploidy 1 \
    --keep-alts --keep-masked-ref \
    --multiallelic-caller \
    --variants-only \
    --threads "$threads" --output-type u \
    | bcftools norm --fasta-ref "$ref_file" \
    --multiallelics - --keep-sum AD \
    --threads "$threads" --output-type v \
    | bcftools annotate \
    --annotations ~/Projeto_Mtb/NGS_helper_files/excludedloci_RLC2021_annot.tab.gz \
    --header-lines ~/Projeto_Mtb/NGS_helper_files/excludedloci_RLC2021_annot.header \
    --columns CHROM,FROM,TO,RLC_tag \
    --threads "$threads" --output-type u \
    | bcftools annotate \
    --annotations ~/Projeto_Mtb/NGS_helper_files/blindspots_mappability_marin2021_annot.tab.gz \
    --header-lines ~/Projeto_Mtb/NGS_helper_files/blindspots_mappability_marin2021_annot.header \
    --columns CHROM,FROM,TO,Mappability \
    --threads "$threads" --output-type u \
    | bcftools annotate \
    --annotations ~/Projeto_Mtb/NGS_helper_files/lineagesnps_annot.tab.gz \
    --header-lines ~/Projeto_Mtb/NGS_helper_files/lineagesnps_annot.header \
    --columns CHROM,POS,REF,ALT,Lineage_tag \
    --threads "$threads" --output-type u \
    | bcftools annotate \
    --annotations ~/Projeto_Mtb/NGS_helper_files/iedbepitopes_annot.tab.gz \
    --header-lines ~/Projeto_Mtb/NGS_helper_files/iedbepitopes_annot.header \
    --columns CHROM,POS,REF,ALT,IEDB_tag \
    --merge-logic IEDB_tag:unique \
    --threads "$threads" --output-type v \
    | bcftools annotate --set-id +'%CHROM:%POS' \
    | bgzip > "$output_dir/${output_prefix}_annotated.vcf.gz"

    if [ -s "$output_dir/${output_prefix}_annotated.vcf.gz" ]; then
        echo "Indexing the final VCF file"
        tabix -p vcf "$output_dir/${output_prefix}_annotated.vcf.gz"
    else
        echo "Error: Failed to create the final VCF file for sample: $sample"
    fi
}

variant_calling() {
    local sample_file="$1"
    local threads=$(nproc)
    echo "Creating equally-sized intervals file for the reference genome"
    create_intervals
    
    echo "Variant calling with bcftools parallel jobs"
    while IFS= read -r sample || [[ -n $sample ]]; do
        echo "Running variant calling for sample: $sample"
        run_variant_calling "$sample"
    done < "$sample_file"    
}

# %%
variant_calling ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Creating equally-sized intervals file for the reference genome
# Creating equally-sized intervals file for the reference genome
# WARNING: Interval :0-0 is smaller than the number of windows requested. Skipping.
#      1	MTB_anc	1	183813
#      2	MTB_anc	183814	367626
#      3	MTB_anc	367627	551439
#      4	MTB_anc	551440	735252
#      5	MTB_anc	735253	919065
#      6	MTB_anc	919066	1102878
#      7	MTB_anc	1102879	1286691
#      8	MTB_anc	1286692	1470504
#      9	MTB_anc	1470505	1654317
#     10	MTB_anc	1654318	1838130
#     11	MTB_anc	1838131	2021943
#     12	MTB_anc	2021944	2205756
#     13	MTB_anc	2205757	2389569
#     14	MTB_anc	2389570	2573382
#     15	MTB_anc	2573383	2757195
#     16	MTB_anc	2757196	2941008
#     17	MTB_anc	2941009	3124821
#     18	MTB_anc	3124822	3308634
#     19	MTB_anc	3308635	3492447
#     20	MTB_anc	3492448	3676260
#     21	MTB_anc	3676261	3860073
#     22	MTB_anc	3860074	4043886
#     23	MTB_anc	4043887	4227699
#     24	MTB_anc	4227700	4411532
# Variant calling with bcftools parallel jobs
# Running variant calling for sample: DRR034421
# Running variant calling for sample: DRR034421
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250
# Lines   total/split/realigned/skipped:	1458/14/127/0
# Indexing the final VCF file
# Running variant calling for sample: DRR130077
# Running variant calling for sample: DRR130077
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250
# Lines   total/split/realigned/skipped:	1543/17/137/0
# Indexing the final VCF file
# Running variant calling for sample: DRR130078
# Running variant calling for sample: DRR130078
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250
# Lines   total/split/realigned/skipped:	1609/29/140/0
# Indexing the final VCF file
# Running variant calling for sample: DRR130093
# Running variant calling for sample: DRR130093
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250
# Lines   total/split/realigned/skipped:	1596/47/134/0
# Indexing the final VCF file

# %% [markdown]
# ## LoFreq + bcftools
#
# Due to its high sensitivity in detecting low-frequency variants, crucial for identifying minor variants, the LoFreq tool was also employed [6]. The process involved two main steps: post-processing and variant calling. In the post-processing step, the `lofreq_postprocessing` function performed indel realignment on duplicated BAM files to refine read alignments around indels, followed by indexing the realigned BAM files. Subsequently, the `LoFreq_calling` function used `lofreq call-parallel` to detect variants in the realigned BAM files, producing VCF files with annotated and high-confidence variant calls.
#
# Additionally, `bcftools` was employed to further refine the variant calls by applying stringent filters and incorporating comprehensive annotations to the VCF files generated. This combined approach generated VCF files with low-frequency variants annotated with information regarding excluded loci, mappability, lineage-specific SNPs, and epitope region

# %%
lofreq_postprocessing() { 
    local sample_file="$1" 
    local genome_reference="$HOME/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta"
    local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads" 
    while IFS= read -r sample || [[ -n $sample ]]; do 
        if [ ! -f "$sra_diretoria/$sample/${sample}_markdup.bam" ]; then 
            echo "No markdup.bam found for: $sample." 
            continue 
        fi 
        lofreq indelqual --dindel -f $genome_reference -o "$sra_diretoria/$sample/${sample}_realigned.bam" "$sra_diretoria/$sample/${sample}_markdup.bam"
        samtools index "$sra_diretoria/$sample/${sample}_realigned.bam"
    done < "$sample_file" 
    echo 'Post-processing with LoFreq completed.'
}

LoFreq_calling() {
    local sample_file="$1" 
    local genome_reference="$HOME/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta"
    local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads" 
    while IFS= read -r sample || [[ -n $sample ]]; do 
        if [ ! -f "$sra_diretoria/$sample/${sample}_realigned.bam" ]; then 
            echo "No realigned.bam found for: $sample." 
            continue 
        fi 
        echo "Performing variant calling for $sample"
        lofreq call-parallel --pp-threads 4 -f $genome_reference -o "$sra_diretoria/$sample/${sample}_lofreq.vcf" "$sra_diretoria/$sample/${sample}_realigned.bam" 
    done < "$sample_file"  
    echo 'Variant calling using LoFreq completed.'
}

# %%
lofreq_postprocessing ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Post-processing with LoFreq completed.

# %%
LoFreq_calling ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Performing variant calling for DRR034421
# INFO [2024-06-16 22:44:16,019]: Using 4 threads with following basic args: lofreq call -f /home/ritanobrega00/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_realigned.bam
#
# INFO [2024-06-16 22:44:16,028]: Adding 12 commands to mp-pool
# Number of substitution tests performed: 619218
# Number of indel tests performed: 0
# INFO [2024-06-16 22:49:51,060]: Executing lofreq filter -i /tmp/lofreq2_call_parallel3c_gxp68/concat.vcf.gz -o /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_lofreq.vcf --snvqual-thresh 78 --indelqual-thresh 20
#
# Performing variant calling for DRR130077
# INFO [2024-06-16 22:49:51,174]: Using 4 threads with following basic args: lofreq call -f /home/ritanobrega00/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_realigned.bam
#
# INFO [2024-06-16 22:49:51,184]: Adding 12 commands to mp-pool
# Number of substitution tests performed: 573042
# Number of indel tests performed: 0
# INFO [2024-06-16 22:56:59,525]: Executing lofreq filter -i /tmp/lofreq2_call_parallelkc6lz639/concat.vcf.gz -o /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_lofreq.vcf --snvqual-thresh 78 --indelqual-thresh 20
#
# Performing variant calling for DRR130078
# INFO [2024-06-16 22:56:59,740]: Using 4 threads with following basic args: lofreq call -f /home/ritanobrega00/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_realigned.bam
#
# INFO [2024-06-16 22:56:59,758]: Adding 12 commands to mp-pool
# Number of substitution tests performed: 505410
# Number of indel tests performed: 0
# INFO [2024-06-16 23:11:07,982]: Executing lofreq filter -i /tmp/lofreq2_call_parallelnvgxr7zi/concat.vcf.gz -o /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_lofreq.vcf --snvqual-thresh 77 --indelqual-thresh 20
#
# Performing variant calling for DRR130093
# INFO [2024-06-16 23:11:08,185]: Using 4 threads with following basic args: lofreq call -f /home/ritanobrega00/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_realigned.bam
#
# INFO [2024-06-16 23:11:08,195]: Adding 12 commands to mp-pool
# Number of substitution tests performed: 972714
# Number of indel tests performed: 0
# INFO [2024-06-16 23:33:05,247]: Executing lofreq filter -i /tmp/lofreq2_call_parallelji0yhzsq/concat.vcf.gz -o /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_lofreq.vcf --snvqual-thresh 80 --indelqual-thresh 20
#
# Variant calling using LoFreq completed.

# %% [markdown]
# ## LoFreq + Bcftools

# %%
lofreq_bcftools() {
    local sample_file="$1"
    local genome_reference="$HOME/Projeto_Mtb/NGS_helper_files/MTB_anc.fasta"
    local sra_directory="$HOME/Projeto_Mtb/Sample_reads"

    echo "Variant calling using LoFreq and bcftools"
    while IFS= read -r sample || [[ -n $sample ]]; do
        local sample_dir="$sra_directory/$sample"
        local lofreq_vcf="$sample_dir/${sample}_lofreq.vcf"
        local bcftools_output="$sample_dir/${sample}_bcftools_lofreq.vcf.gz"

        if [ -s "$lofreq_vcf" ]; then
            echo "Running bcftools processing for sample: $sample"
            bgzip -c "$sample_dir/${sample}_lofreq.vcf" > "$sample_dir/${sample}_lofreq.vcf.gz"
            tabix -p vcf "$sample_dir/${sample}_lofreq.vcf.gz"
            bcftools annotate --annotations ~/Projeto_Mtb/NGS_helper_files/excludedloci_RLC2021_annot.tab.gz \
                             --header-lines ~/Projeto_Mtb/NGS_helper_files/excludedloci_RLC2021_annot.header \
                             --columns CHROM,FROM,TO,RLC_tag \
                             --threads "$(nproc)" --output-type u "$lofreq_vcf.gz" \
            | bcftools annotate --annotations ~/Projeto_Mtb/NGS_helper_files/blindspots_mappability_marin2021_annot.tab.gz \
                                --header-lines ~/Projeto_Mtb/NGS_helper_files/blindspots_mappability_marin2021_annot.header \
                                --columns CHROM,FROM,TO,Mappability \
                                --threads "$(nproc)" --output-type u \
            | bcftools annotate --annotations ~/Projeto_Mtb/NGS_helper_files/lineagesnps_annot.tab.gz \
                                --header-lines ~/Projeto_Mtb/NGS_helper_files/lineagesnps_annot.header \
                                --columns CHROM,POS,REF,ALT,Lineage_tag \
                                --threads "$(nproc)" --output-type u \
            | bcftools annotate --annotations ~/Projeto_Mtb/NGS_helper_files/iedbepitopes_annot.tab.gz \
                                --header-lines ~/Projeto_Mtb/NGS_helper_files/iedbepitopes_annot.header \
                                --columns CHROM,POS,REF,ALT,IEDB_tag \
                                --merge-logic IEDB_tag:unique \
                                --threads "$(nproc)" --output-type v \
            | bcftools annotate --set-id +'%CHROM:%POS' \
            | bgzip > "$bcftools_output"

            if [ -s "$bcftools_output" ]; then
                echo "Indexing the final annotated VCF file for sample: $sample"
                tabix -p vcf "$bcftools_output"
            else
                echo "Error: Failed to create the final annotated VCF file for sample: $sample"
            fi
        else
            echo "Error: Failed to generate LoFreq VCF for sample: $sample"
        fi
    done < "$sample_file"

    echo "Variant calling using LoFreq and bcftools completed."
}

# %%
lofreq_bcftools ~/Projeto_Mtb/list_isolates_SRA.txt
# Out:
# Variant calling using LoFreq and bcftools
# Running bcftools processing for sample: DRR034421
# Indexing the final annotated VCF file for sample: DRR034421
# Running bcftools processing for sample: DRR130077
# Indexing the final annotated VCF file for sample: DRR130077
# Running bcftools processing for sample: DRR130078
# Indexing the final annotated VCF file for sample: DRR130078
# Running bcftools processing for sample: DRR130093
# Indexing the final annotated VCF file for sample: DRR130093
# Variant calling using LoFreq and bcftools completed.

# %% [markdown]
# # Compare VCF files from different variant callers

# %%
tabix -p vcf "$HOME/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_lofreq.vcf.gz"
# Out:
# [tabix] the index file exists. Please use '-f' to overwrite.
# : 1

# %%
vcf_files=("DRR130078_simple.vcf" "DRR130078_bcftools_varsonly_annotated.vcf" "DRR130078_lofreq.vcf")
for vcf_file in "${vcf_files[@]}"
do
    echo "Variants identified in $vcf_file:"
    grep -c "^MTB_anc" $HOME/Projeto_Mtb/Sample_reads/DRR130078/"$vcf_file"
done
# Out:
# Variants identified in DRR130078_simple.vcf:
# 1576
# Variants identified in DRR130078_bcftools_varsonly_annotated.vcf:
# 1640
# Variants identified in DRR130078_lofreq.vcf:
# 1743

# %%
vcf_files=("DRR130077_simple.vcf" "DRR130077_bcftools_varsonly_annotated.vcf" "DRR130077_lofreq.vcf")
for vcf_file in "${vcf_files[@]}"
do
    echo "Variants identified in $vcf_file:"
    grep -c "^MTB_anc" $HOME/Projeto_Mtb/Sample_reads/DRR130077/"$vcf_file"
done
# Out:
# Variants identified in: DRR130077_simple.vcf
# 1532
# Variants identified in: DRR130077_bcftools_varsonly_annotated.vcf
# 1560
# Variants identified in: DRR130077_lofreq.vcf
# 1616

# %%
vcf_files=("DRR034421_simple.vcf" "DRR034421_bcftools_varsonly_annotated.vcf" "DRR034421_lofreq.vcf")
for vcf_file in "${vcf_files[@]}"
do
    echo "Variants identified in $vcf_file:"
    grep -c "^MTB_anc" $HOME/Projeto_Mtb/Sample_reads/DRR034421/"$vcf_file"
done
# Out:
# Variants identified in: DRR034421_simple.vcf
# 1417
# Variants identified in: DRR034421_bcftools_varsonly_annotated.vcf
# 1472
# Variants identified in: DRR034421_lofreq.vcf
# 1346

# %%
vcf_files=("DRR130093_simple.vcf" "DRR130093_bcftools_varsonly_annotated.vcf" "DRR130093_lofreq.vcf.gz")
for vcf_file in "${vcf_files[@]}"
do
    echo "Variants identified in $vcf_file:"
    
    grep -c "^MTB_anc" $HOME/Projeto_Mtb/Sample_reads/DRR130093/"$vcf_file"
done
# Out:
# Variants identified in DRR130093_simple.vcf:
# 1571
# Variants identified in DRR130093_bcftools_varsonly_annotated.vcf:
# 1645
# Variants identified in DRR130093_lofreq.vcf:
# 1723

# %%
comparing_VCF(){
    local sample="$1" 
    local sra_diretoria="$HOME/Projeto_Mtb/Sample_reads" 

    echo "Comparing VCF files for $sample:"
    bgzip -c "$sra_diretoria/${sample}/${sample}_simple.vcf" > "$sra_diretoria/${sample}/${sample}_simple.vcf.gz"
    bgzip -c "$sra_diretoria/${sample}/${sample}_bcftools_varsonly_annotated.vcf" > "$sra_diretoria/${sample}/${sample}_bcftools_varsonly_annotated.vcf.gz"

    tabix -p vcf "$sra_diretoria/${sample}/${sample}_simple.vcf.gz"
    tabix -p vcf "$sra_diretoria/${sample}/${sample}_bcftools_varsonly_annotated.vcf.gz"
    tabix -p vcf "$sra_diretoria/${sample}/${sample}_bcftools_lofreq.vcf.gz"
    
    vcf-compare "$sra_diretoria/${sample}/${sample}_simple.vcf.gz" "$sra_diretoria/${sample}/${sample}_bcftools_varsonly_annotated.vcf.gz" "$sra_diretoria/${sample}/${sample}_bcftools_lofreq.vcf.gz" 
}

# %%
comparing_VCF DRR130078
# Out:
# Comparing VCF files for DRR130078:
# [tabix] the index file exists. Please use '-f' to overwrite.
# # This file was generated by vcf-compare.
# # The command line was: vcf-compare(v0.1.14-12-gcdb80b8) /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_simple.vcf.gz /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_varsonly_annotated.vcf.gz /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_lofreq.vcf.gz
# #
# #VN 'Venn-Diagram Numbers'. Use `grep ^VN | cut -f 2-` to extract this part.
# #VN The columns are:
# #VN        1  .. number of sites unique to this particular combination of files
# #VN        2- .. combination of files and space-separated number, a fraction of sites in the file
# VN	5	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_lofreq.vcf.gz (0.3%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_varsonly_annotated.vcf.gz (0.3%)
# VN	19	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_simple.vcf.gz (1.2%)
# VN	22	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_lofreq.vcf.gz (1.3%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_simple.vcf.gz (1.4%)
# VN	69	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_varsonly_annotated.vcf.gz (4.3%)
# VN	266	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_varsonly_annotated.vcf.gz (16.5%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_simple.vcf.gz (16.9%)
# VN	447	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_lofreq.vcf.gz (25.6%)
# VN	1269	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_lofreq.vcf.gz (72.8%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_varsonly_annotated.vcf.gz (78.9%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_simple.vcf.gz (80.5%)
# #SN Summary Numbers. Use `grep ^SN | cut -f 2-` to extract this part.
# SN	Number of REF matches:	1269
# SN	Number of ALT matches:	1253
# SN	Number of REF mismatches:	0
# SN	Number of ALT mismatches:	16
# SN	Number of samples in GT comparison:	0
# # Number of sites lost due to grouping (e.g. duplicate sites): lost, %lost, read, reported, file
# SN	Number of lost sites:	31	1.9%	1640	1609	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130078/DRR130078_bcftools_varsonly_annotated.vcf.gz

# %%
comparing_VCF DRR130077
# Out:
# Comparing VCF files for DRR130077:
# # This file was generated by vcf-compare.
# # The command line was: vcf-compare(v0.1.14-12-gcdb80b8) /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_simple.vcf.gz /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_bcftools_varsonly_annotated.vcf.gz /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_lofreq.vcf.gz
# #
# #VN 'Venn-Diagram Numbers'. Use `grep ^VN | cut -f 2-` to extract this part.
# #VN The columns are:
# #VN        1  .. number of sites unique to this particular combination of files
# #VN        2- .. combination of files and space-separated number, a fraction of sites in the file
# VN	3	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_bcftools_varsonly_annotated.vcf.gz (0.2%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_lofreq.vcf.gz (0.2%)
# VN	21	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_simple.vcf.gz (1.4%)
# VN	24	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_lofreq.vcf.gz (1.5%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_simple.vcf.gz (1.6%)
# VN	53	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_bcftools_varsonly_annotated.vcf.gz (3.4%)
# VN	234	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_bcftools_varsonly_annotated.vcf.gz (15.2%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_simple.vcf.gz (15.3%)
# VN	336	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_lofreq.vcf.gz (20.8%)
# VN	1253	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_bcftools_varsonly_annotated.vcf.gz (81.2%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_lofreq.vcf.gz (77.5%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_simple.vcf.gz (81.8%)
# #SN Summary Numbers. Use `grep ^SN | cut -f 2-` to extract this part.
# SN	Number of REF matches:	1252
# SN	Number of ALT matches:	1241
# SN	Number of REF mismatches:	1
# SN	Number of ALT mismatches:	11
# SN	Number of samples in GT comparison:	0
# # Number of sites lost due to grouping (e.g. duplicate sites): lost, %lost, read, reported, file
# SN	Number of lost sites:	17	1.1%	1560	1543	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130077/DRR130077_bcftools_varsonly_annotated.vcf.gz

# %%
comparing_VCF DRR034421
# Out:
# Comparing VCF files for DRR034421:
# [tabix] the index file exists. Please use '-f' to overwrite.
# # This file was generated by vcf-compare.
# # The command line was: vcf-compare(v0.1.14-12-gcdb80b8) /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_simple.vcf.gz /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_varsonly_annotated.vcf.gz /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_lofreq.vcf.gz
# #
# #VN 'Venn-Diagram Numbers'. Use `grep ^VN | cut -f 2-` to extract this part.
# #VN The columns are:
# #VN        1  .. number of sites unique to this particular combination of files
# #VN        2- .. combination of files and space-separated number, a fraction of sites in the file
# VN	4	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_lofreq.vcf.gz (0.3%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_varsonly_annotated.vcf.gz (0.3%)
# VN	4	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_lofreq.vcf.gz (0.3%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_simple.vcf.gz (0.3%)
# VN	16	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_simple.vcf.gz (1.1%)
# VN	57	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_varsonly_annotated.vcf.gz (3.9%)
# VN	220	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_lofreq.vcf.gz (16.3%)
# VN	279	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_varsonly_annotated.vcf.gz (19.1%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_simple.vcf.gz (19.7%)
# VN	1118	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_lofreq.vcf.gz (83.1%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_varsonly_annotated.vcf.gz (76.7%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_simple.vcf.gz (78.9%)
# #SN Summary Numbers. Use `grep ^SN | cut -f 2-` to extract this part.
# SN	Number of REF matches:	1118
# SN	Number of ALT matches:	1108
# SN	Number of REF mismatches:	0
# SN	Number of ALT mismatches:	10
# SN	Number of samples in GT comparison:	0
# # Number of sites lost due to grouping (e.g. duplicate sites): lost, %lost, read, reported, file
# SN	Number of lost sites:	14	1.0%	1472	1458	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR034421/DRR034421_bcftools_varsonly_annotated.vcf.gz

# %%
comparing_VCF DRR130093
# Out:
# Comparing VCF files for DRR130093:
# [tabix] the index file exists. Please use '-f' to overwrite.
# # This file was generated by vcf-compare.
# # The command line was: vcf-compare(v0.1.14-12-gcdb80b8) /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_simple.vcf.gz /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_varsonly_annotated.vcf.gz /home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_lofreq.vcf.gz
# #
# #VN 'Venn-Diagram Numbers'. Use `grep ^VN | cut -f 2-` to extract this part.
# #VN The columns are:
# #VN        1  .. number of sites unique to this particular combination of files
# #VN        2- .. combination of files and space-separated number, a fraction of sites in the file
# VN	3	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_lofreq.vcf.gz (0.2%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_varsonly_annotated.vcf.gz (0.2%)
# VN	20	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_lofreq.vcf.gz (1.2%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_simple.vcf.gz (1.3%)
# VN	28	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_simple.vcf.gz (1.8%)
# VN	70	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_varsonly_annotated.vcf.gz (4.4%)
# VN	247	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_varsonly_annotated.vcf.gz (15.5%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_simple.vcf.gz (15.7%)
# VN	424	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_lofreq.vcf.gz (24.6%)
# VN	1276	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_lofreq.vcf.gz (74.1%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_varsonly_annotated.vcf.gz (79.9%)	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_simple.vcf.gz (81.2%)
# #SN Summary Numbers. Use `grep ^SN | cut -f 2-` to extract this part.
# SN	Number of REF matches:	1276
# SN	Number of ALT matches:	1239
# SN	Number of REF mismatches:	0
# SN	Number of ALT mismatches:	37
# SN	Number of samples in GT comparison:	0
# # Number of sites lost due to grouping (e.g. duplicate sites): lost, %lost, read, reported, file
# SN	Number of lost sites:	49	3.0%	1645	1596	/home/ritanobrega00/Projeto_Mtb/Sample_reads/DRR130093/DRR130093_bcftools_varsonly_annotated.vcf.gz

# %% [markdown]
# # References:
#
# [1] https://github.com/ncbi/sra-tools/wiki/08.-prefetch-and-fasterq-dump
#
# [2] https://jgi.doe.gov/data-and-tools/software-tools/bbtools/bb-tools-user-guide/bbduk-guide/
#
# [3]  https://github.com/lh3/bwa
#
# [4] https://github.com/brentp/mosdepth
#
# [5] https://samtools.github.io/bcftools/bcftools.html
#
# [6] Wilm, A., Aw, P. P., Bertrand, D., Yeo, G. H., Ong, S. H., Wong, C. H., Khor, C. C., Petric, R., Hibberd, M. L., & Nagarajan, N. (2012). LoFreq: a sequence-quality aware, ultra-sensitive variant caller for uncovering cell-population heterogeneity from high-throughput sequencing datasets. Nucleic acids research, 40(22), 11189–11201. https://doi.org/10.1093/nar/gks918
